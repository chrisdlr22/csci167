# %% [markdown]
# <a href="https://colab.research.google.com/github/chrisdlr22/csci167/blob/main/12_3_Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 12.3: Tokenization**
#
# This notebook builds set of tokens from a text string as in figure 12.8 of the book.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# I adapted this code from *SOMEWHERE*.  If anyone recognizes it, can you let me know and I will give the proper attribution or rewrite if the license is not permissive.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
import re, collections

# %%
text = "a sailor went to sea sea sea "+\
                  "to see what he could see see see "+\
                  "but all that he could see see see "+\
                  "was the bottom of the deep blue sea sea sea"

# %% [markdown]
# Tokenize the input sentence To begin with the tokens are the individual letters and the </w> whitespace token. So, we represent each word in terms of these tokens with spaces between the tokens to delineate them.
#
# The tokenized text is stored in a structure that represents each word as tokens together with the count of how often that word occurs.  We'll call this the *vocabulary*.

# %%
def initialize_vocabulary(text):
  vocab = collections.defaultdict(int)
  words = text.strip().split()
  for word in words:
      vocab[' '.join(list(word)) + ' </w>'] += 1
  return vocab

# %%
vocab = initialize_vocabulary(text)
print('Vocabulary: {}'.format(vocab))
print('Size of vocabulary: {}'.format(len(vocab)))
# Out:
# Vocabulary: defaultdict(<class 'int'>, {'a </w>': 1, 's a i l o r </w>': 1, 'w e n t </w>': 1, 't o </w>': 2, 's e a </w>': 6, 's e e </w>': 7, 'w h a t </w>': 1, 'h e </w>': 2, 'c o u l d </w>': 2, 'b u t </w>': 1, 'a l l </w>': 1, 't h a t </w>': 1, 'w a s </w>': 1, 't h e </w>': 2, 'b o t t o m </w>': 1, 'o f </w>': 1, 'd e e p </w>': 1, 'b l u e </w>': 1})
# Size of vocabulary: 18

# %% [markdown]
# Find all the tokens in the current vocabulary and their frequencies

# %%
def get_tokens_and_frequencies(vocab):
  tokens = collections.defaultdict(int)
  for word, freq in vocab.items():
      word_tokens = word.split()
      for token in word_tokens:
          tokens[token] += freq
  return tokens

# %%
tokens = get_tokens_and_frequencies(vocab)
print('Tokens: {}'.format(tokens))
print('Number of tokens: {}'.format(len(tokens)))
# Out:
# Tokens: defaultdict(<class 'int'>, {'a': 12, '</w>': 33, 's': 15, 'i': 1, 'l': 6, 'o': 8, 'r': 1, 'w': 3, 'e': 28, 'n': 1, 't': 11, 'h': 6, 'c': 2, 'u': 4, 'd': 3, 'b': 3, 'm': 1, 'f': 1, 'p': 1})
# Number of tokens: 19

# %% [markdown]
# Find each pair of adjacent tokens in the vocabulary
# and count them.  We will subsequently merge the most frequently occurring pair.

# %%
def get_pairs_and_counts(vocab):
    pairs = collections.defaultdict(int)
    for word, freq in vocab.items():
        symbols = word.split()
        for i in range(len(symbols)-1):
            pairs[symbols[i],symbols[i+1]] += freq
    return pairs

# %%
pairs = get_pairs_and_counts(vocab)
print('Pairs: {}'.format(pairs))
print('Number of distinct pairs: {}'.format(len(pairs)))

most_frequent_pair = max(pairs, key=pairs.get)
print('Most frequent pair: {}'.format(most_frequent_pair))
# Out:
# Pairs: defaultdict(<class 'int'>, {('a', '</w>'): 7, ('s', 'a'): 1, ('a', 'i'): 1, ('i', 'l'): 1, ('l', 'o'): 1, ('o', 'r'): 1, ('r', '</w>'): 1, ('w', 'e'): 1, ('e', 'n'): 1, ('n', 't'): 1, ('t', '</w>'): 4, ('t', 'o'): 3, ('o', '</w>'): 2, ('s', 'e'): 13, ('e', 'a'): 6, ('e', 'e'): 8, ('e', '</w>'): 12, ('w', 'h'): 1, ('h', 'a'): 2, ('a', 't'): 2, ('h', 'e'): 4, ('c', 'o'): 2, ('o', 'u'): 2, ('u', 'l'): 2, ('l', 'd'): 2, ('d', '</w>'): 2, ('b', 'u'): 1, ('u', 't'): 1, ('a', 'l'): 1, ('l', 'l'): 1, ('l', '</w>'): 1, ('t', 'h'): 3, ('w', 'a'): 1, ('a', 's'): 1, ('s', '</w>'): 1, ('b', 'o'): 1, ('o', 't'): 1, ('t', 't'): 1, ('o', 'm'): 1, ('m', '</w>'): 1, ('o', 'f'): 1, ('f', '</w>'): 1, ('d', 'e'): 1, ('e', 'p'): 1, ('p', '</w>'): 1, ('b', 'l'): 1, ('l', 'u'): 1, ('u', 'e'): 1})
# Number of distinct pairs: 48
# Most frequent pair: ('s', 'e')

# %% [markdown]
# Merge the instances of the best pair in the vocabulary

# %%
def merge_pair_in_vocabulary(pair, vocab_in):
    vocab_out = {}
    bigram = re.escape(' '.join(pair))
    p = re.compile(r'(?<!\S)' + bigram + r'(?!\S)')
    for word in vocab_in:
        word_out = p.sub(''.join(pair), word)
        vocab_out[word_out] = vocab_in[word]
    return vocab_out

# %%
vocab = merge_pair_in_vocabulary(most_frequent_pair, vocab)
print('Vocabulary: {}'.format(vocab))
print('Size of vocabulary: {}'.format(len(vocab)))
# Out:
# Vocabulary: {'a </w>': 1, 's a i l o r </w>': 1, 'w e n t </w>': 1, 't o </w>': 2, 'se a </w>': 6, 'se e </w>': 7, 'w h a t </w>': 1, 'h e </w>': 2, 'c o u l d </w>': 2, 'b u t </w>': 1, 'a l l </w>': 1, 't h a t </w>': 1, 'w a s </w>': 1, 't h e </w>': 2, 'b o t t o m </w>': 1, 'o f </w>': 1, 'd e e p </w>': 1, 'b l u e </w>': 1}
# Size of vocabulary: 18

# %% [markdown]
# Update the tokens, which now include the best token 'se'

# %%
tokens = get_tokens_and_frequencies(vocab)
print('Tokens: {}'.format(tokens))
print('Number of tokens: {}'.format(len(tokens)))
# Out:
# Tokens: defaultdict(<class 'int'>, {'a': 12, '</w>': 33, 's': 2, 'i': 1, 'l': 6, 'o': 8, 'r': 1, 'w': 3, 'e': 15, 'n': 1, 't': 11, 'se': 13, 'h': 6, 'c': 2, 'u': 4, 'd': 3, 'b': 3, 'm': 1, 'f': 1, 'p': 1})
# Number of tokens: 20

# %% [markdown]
# Now let's write the full tokenization routine

# %%
def tokenize(text, num_merges):
  vocab = initialize_vocabulary(text)

  for i in range(num_merges):
    tokens = get_tokens_and_frequencies(vocab)
    pairs = get_pairs_and_counts(vocab)
    if not pairs:
        break
    most_frequent_pair = max(pairs, key=pairs.get)
    print(f'Merge iteration {i+1}: Most frequent pair: {most_frequent_pair}')
    vocab = merge_pair_in_vocabulary(most_frequent_pair, vocab)
    tokens = get_tokens_and_frequencies(vocab)

  return tokens, vocab

# %%
tokens, vocab = tokenize(text, num_merges=22)
# Out:
# Merge iteration 1: Most frequent pair: ('s', 'e')
# Merge iteration 2: Most frequent pair: ('e', '</w>')
# Merge iteration 3: Most frequent pair: ('a', '</w>')
# Merge iteration 4: Most frequent pair: ('se', 'e</w>')
# Merge iteration 5: Most frequent pair: ('se', 'a</w>')
# Merge iteration 6: Most frequent pair: ('t', '</w>')
# Merge iteration 7: Most frequent pair: ('h', 'e</w>')
# Merge iteration 8: Most frequent pair: ('t', 'o')
# Merge iteration 9: Most frequent pair: ('to', '</w>')
# Merge iteration 10: Most frequent pair: ('h', 'a')
# Merge iteration 11: Most frequent pair: ('ha', 't</w>')
# Merge iteration 12: Most frequent pair: ('c', 'o')
# Merge iteration 13: Most frequent pair: ('co', 'u')
# Merge iteration 14: Most frequent pair: ('cou', 'l')
# Merge iteration 15: Most frequent pair: ('coul', 'd')
# Merge iteration 16: Most frequent pair: ('could', '</w>')
# Merge iteration 17: Most frequent pair: ('t', 'he</w>')
# Merge iteration 18: Most frequent pair: ('s', 'a')
# Merge iteration 19: Most frequent pair: ('sa', 'i')
# Merge iteration 20: Most frequent pair: ('sai', 'l')
# Merge iteration 21: Most frequent pair: ('sail', 'o')
# Merge iteration 22: Most frequent pair: ('sailo', 'r')

# %%
print('Tokens: {}'.format(tokens))
print('Number of tokens: {}'.format(len(tokens)))
print('Vocabulary: {}'.format(vocab))
print('Size of vocabulary: {}'.format(len(vocab)))
# Out:
# Tokens: defaultdict(<class 'int'>, {'a</w>': 1, 'sailor': 1, '</w>': 6, 'w': 3, 'e': 3, 'n': 1, 't</w>': 2, 'to</w>': 2, 'sea</w>': 6, 'see</w>': 7, 'hat</w>': 2, 'he</w>': 2, 'could</w>': 2, 'b': 3, 'u': 2, 'a': 2, 'l': 3, 't': 2, 's': 1, 'the</w>': 2, 'o': 2, 'to': 1, 'm': 1, 'f': 1, 'd': 1, 'p': 1, 'e</w>': 1})
# Number of tokens: 27
# Vocabulary: {'a</w>': 1, 'sailor </w>': 1, 'w e n t</w>': 1, 'to</w>': 2, 'sea</w>': 6, 'see</w>': 7, 'w hat</w>': 1, 'he</w>': 2, 'could</w>': 2, 'b u t</w>': 1, 'a l l </w>': 1, 't hat</w>': 1, 'w a s </w>': 1, 'the</w>': 2, 'b o t to m </w>': 1, 'o f </w>': 1, 'd e e p </w>': 1, 'b l u e</w>': 1}
# Size of vocabulary: 18

# %% [markdown]
# TODO - Consider the input text:
#
# "How much wood could a woodchuck chuck if a woodchuck could chuck wood"
#
# How many tokens will there be initially and what will they be?
# How many tokens will there be if we run the tokenization routine for the maximum number of iterations (merges)?
#
# When you've made your predictions, run the code and see if you are correct.

# %% [markdown]
# There should be at least 14 tokens based on the all the unique characts. There are 8 unique words so after maximum merges, there are 8 tokens.

# %%
new_text = "How much wood could a woodchuck chuck if a woodchuck could chuck wood"
print(f"Input text: {new_text}")
# Out:
# Input text: How much wood could a woodchuck chuck if a woodchuck could chuck wood

# %%
initial_vocab = initialize_vocabulary(new_text)
initial_tokens = get_tokens_and_frequencies(initial_vocab)
print(f'\nInitially, there are {len(initial_tokens)} tokens.')
print(f'Initial tokens: {list(initial_tokens.keys())}')
final_tokens, final_vocab = tokenize(new_text, num_merges=100)
print(f'\nAfter maximum merges, there are {len(final_tokens)} tokens.')
print(f'Final tokens: {list(final_tokens.keys())}')
# Out:
# Initially, there are 14 tokens.
# Initial tokens: ['H', 'o', 'w', '</w>', 'm', 'u', 'c', 'h', 'd', 'l', 'a', 'k', 'i', 'f']
# Merge iteration 1: Most frequent pair: ('u', 'c')
# Merge iteration 2: Most frequent pair: ('w', 'o')
# Merge iteration 3: Most frequent pair: ('wo', 'o')
# Merge iteration 4: Most frequent pair: ('woo', 'd')
# Merge iteration 5: Most frequent pair: ('c', 'h')
# Merge iteration 6: Most frequent pair: ('ch', 'uc')
# Merge iteration 7: Most frequent pair: ('chuc', 'k')
# Merge iteration 8: Most frequent pair: ('chuck', '</w>')
# Merge iteration 9: Most frequent pair: ('wood', '</w>')
# Merge iteration 10: Most frequent pair: ('c', 'o')
# Merge iteration 11: Most frequent pair: ('co', 'u')
# Merge iteration 12: Most frequent pair: ('cou', 'l')
# Merge iteration 13: Most frequent pair: ('coul', 'd')
# Merge iteration 14: Most frequent pair: ('could', '</w>')
# Merge iteration 15: Most frequent pair: ('a', '</w>')
# Merge iteration 16: Most frequent pair: ('wood', 'chuck</w>')
# Merge iteration 17: Most frequent pair: ('H', 'o')
# Merge iteration 18: Most frequent pair: ('Ho', 'w')
# Merge iteration 19: Most frequent pair: ('How', '</w>')
# Merge iteration 20: Most frequent pair: ('m', 'uc')
# Merge iteration 21: Most frequent pair: ('muc', 'h')
# Merge iteration 22: Most frequent pair: ('much', '</w>')
# Merge iteration 23: Most frequent pair: ('i', 'f')
# Merge iteration 24: Most frequent pair: ('if', '</w>')
#
# After maximum merges, there are 8 tokens.
# Final tokens: ['How</w>', 'much</w>', 'wood</w>', 'could</w>', 'a</w>', 'woodchuck</w>', 'chuck</w>', 'if</w>']
