# %% [markdown]
# <a href="https://colab.research.google.com/github/chrisdlr22/csci167/blob/main/Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-e4kb3kyi
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-e4kb3kyi
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=1fa4e8f2c427cb6a345e60ac06105d282573baa99a66d5208a80feb438c496d7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gohi8ygb/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero? 100
# 2.   At what capacity do you expect the first minima of the double descent curve to appear? 100
# 3. At what capacity do you expect the maximum of the double descent curve to appear? 400

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.304111, train error 90.38,  test loss 2.304459, test error 90.80
# Epoch   100, train loss 2.284553, train error 87.55,  test loss 2.303236, test error 88.25
# Epoch   200, train loss 1.922302, train error 72.95,  test loss 1.771285, test error 69.95
# Epoch   300, train loss 1.923197, train error 72.47,  test loss 1.746937, test error 70.82
# Epoch   400, train loss 1.905433, train error 71.32,  test loss 1.734004, test error 69.45
# Epoch   500, train loss 1.905295, train error 70.72,  test loss 1.733204, test error 69.45
# Epoch   600, train loss 1.902545, train error 71.15,  test loss 1.738219, test error 68.78
# Epoch   700, train loss 1.901089, train error 71.78,  test loss 1.733908, test error 68.68
# Epoch   800, train loss 1.903245, train error 72.03,  test loss 1.736696, test error 68.90
# Epoch   900, train loss 1.905232, train error 71.68,  test loss 1.743306, test error 68.95
# Training model with   4 hidden variables
# Epoch     0, train loss 2.297523, train error 87.90,  test loss 2.295025, test error 87.90
# Epoch   100, train loss 1.828679, train error 68.35,  test loss 1.704428, test error 67.47
# Epoch   200, train loss 1.725160, train error 62.88,  test loss 1.547492, test error 58.95
# Epoch   300, train loss 1.714373, train error 61.70,  test loss 1.542459, test error 59.40
# Epoch   400, train loss 1.700085, train error 61.40,  test loss 1.517283, test error 59.28
# Epoch   500, train loss 1.699552, train error 62.08,  test loss 1.519410, test error 59.90
# Epoch   600, train loss 1.696131, train error 61.10,  test loss 1.514433, test error 59.17
# Epoch   700, train loss 1.696808, train error 62.12,  test loss 1.517451, test error 59.05
# Epoch   800, train loss 1.697924, train error 61.60,  test loss 1.514927, test error 58.20
# Epoch   900, train loss 1.691377, train error 61.58,  test loss 1.510329, test error 58.90
# Training model with   6 hidden variables
# Epoch     0, train loss 2.285475, train error 86.30,  test loss 2.284233, test error 86.50
# Epoch   100, train loss 1.699590, train error 62.05,  test loss 1.526480, test error 59.65
# Epoch   200, train loss 1.648461, train error 59.60,  test loss 1.490315, test error 56.85
# Epoch   300, train loss 1.649290, train error 59.20,  test loss 1.508794, test error 57.80
# Epoch   400, train loss 1.624510, train error 58.70,  test loss 1.491511, test error 57.30
# Epoch   500, train loss 1.628335, train error 58.83,  test loss 1.534382, test error 58.75
# Epoch   600, train loss 1.608850, train error 58.05,  test loss 1.513856, test error 57.85
# Epoch   700, train loss 1.610844, train error 57.92,  test loss 1.514409, test error 57.40
# Epoch   800, train loss 1.610071, train error 57.85,  test loss 1.520551, test error 57.22
# Epoch   900, train loss 1.606490, train error 58.22,  test loss 1.516718, test error 57.67
# Training model with   8 hidden variables
# Epoch     0, train loss 2.205050, train error 84.55,  test loss 2.190405, test error 84.10
# Epoch   100, train loss 1.579143, train error 55.58,  test loss 1.431878, test error 54.38
# Epoch   200, train loss 1.537155, train error 53.92,  test loss 1.394135, test error 52.55
# Epoch   300, train loss 1.519073, train error 53.22,  test loss 1.397774, test error 53.20
# Epoch   400, train loss 1.508818, train error 52.50,  test loss 1.386585, test error 52.45
# Epoch   500, train loss 1.496620, train error 52.83,  test loss 1.384662, test error 52.78
# Epoch   600, train loss 1.488679, train error 52.85,  test loss 1.392028, test error 53.25
# Epoch   700, train loss 1.487994, train error 52.75,  test loss 1.392869, test error 53.42
# Epoch   800, train loss 1.475013, train error 52.45,  test loss 1.389536, test error 52.88
# Epoch   900, train loss 1.480727, train error 52.20,  test loss 1.401394, test error 52.70
# Training model with  10 hidden variables
# Epoch     0, train loss 2.208519, train error 81.20,  test loss 2.200896, test error 80.88
# Epoch   100, train loss 1.566941, train error 54.55,  test loss 1.469732, test error 55.42
# Epoch   200, train loss 1.493018, train error 51.03,  test loss 1.407249, test error 53.62
# Epoch   300, train loss 1.474522, train error 51.10,  test loss 1.402438, test error 53.42
# Epoch   400, train loss 1.456325, train error 50.05,  test loss 1.396583, test error 52.78
# Epoch   500, train loss 1.437107, train error 49.62,  test loss 1.395646, test error 52.30
# Epoch   600, train loss 1.431181, train error 48.80,  test loss 1.410625, test error 52.20
# Epoch   700, train loss 1.426114, train error 49.00,  test loss 1.402746, test error 52.25
# Epoch   800, train loss 1.424916, train error 48.92,  test loss 1.417482, test error 53.10
# Epoch   900, train loss 1.426288, train error 48.65,  test loss 1.423097, test error 53.78
# Training model with  14 hidden variables
# Epoch     0, train loss 2.120321, train error 80.47,  test loss 2.083351, test error 79.50
# Epoch   100, train loss 1.499786, train error 52.05,  test loss 1.424289, test error 54.40
# Epoch   200, train loss 1.408102, train error 49.35,  test loss 1.405524, test error 52.85
# Epoch   300, train loss 1.346099, train error 46.33,  test loss 1.404612, test error 51.22
# Epoch   400, train loss 1.314432, train error 45.12,  test loss 1.426317, test error 51.83
# Epoch   500, train loss 1.303836, train error 44.38,  test loss 1.429875, test error 52.15
# Epoch   600, train loss 1.296503, train error 44.72,  test loss 1.442572, test error 52.53
# Epoch   700, train loss 1.290339, train error 44.62,  test loss 1.445303, test error 51.83
# Epoch   800, train loss 1.277020, train error 44.42,  test loss 1.456719, test error 52.15
# Epoch   900, train loss 1.280183, train error 43.50,  test loss 1.467197, test error 51.12
# Training model with  18 hidden variables
# Epoch     0, train loss 2.250412, train error 82.97,  test loss 2.212272, test error 81.12
# Epoch   100, train loss 1.360310, train error 45.70,  test loss 1.321967, test error 49.15
# Epoch   200, train loss 1.270794, train error 43.28,  test loss 1.344496, test error 49.58
# Epoch   300, train loss 1.219765, train error 42.30,  test loss 1.407594, test error 51.00
# Epoch   400, train loss 1.176048, train error 40.28,  test loss 1.417234, test error 50.28
# Epoch   500, train loss 1.171525, train error 41.12,  test loss 1.480763, test error 52.17
# Epoch   600, train loss 1.154495, train error 40.35,  test loss 1.500908, test error 52.15
# Epoch   700, train loss 1.144132, train error 39.72,  test loss 1.512933, test error 52.25
# Epoch   800, train loss 1.136223, train error 39.70,  test loss 1.516087, test error 52.28
# Epoch   900, train loss 1.130554, train error 39.72,  test loss 1.560070, test error 52.85
# Training model with  22 hidden variables
# Epoch     0, train loss 2.239723, train error 83.45,  test loss 2.221246, test error 83.10
# Epoch   100, train loss 1.283310, train error 42.53,  test loss 1.348507, test error 50.25
# Epoch   200, train loss 1.162065, train error 38.65,  test loss 1.385382, test error 49.80
# Epoch   300, train loss 1.094374, train error 36.62,  test loss 1.455766, test error 51.33
# Epoch   400, train loss 1.053885, train error 35.50,  test loss 1.525275, test error 50.90
# Epoch   500, train loss 1.030475, train error 34.90,  test loss 1.594070, test error 51.10
# Epoch   600, train loss 1.015457, train error 33.50,  test loss 1.647181, test error 51.95
# Epoch   700, train loss 1.000430, train error 33.53,  test loss 1.666005, test error 51.45
# Epoch   800, train loss 0.989335, train error 32.82,  test loss 1.739300, test error 53.30
# Epoch   900, train loss 0.969336, train error 32.22,  test loss 1.776725, test error 52.85
# Training model with  26 hidden variables
# Epoch     0, train loss 2.160352, train error 80.32,  test loss 2.133971, test error 79.55
# Epoch   100, train loss 1.221984, train error 41.08,  test loss 1.329869, test error 49.50
# Epoch   200, train loss 1.077339, train error 35.35,  test loss 1.428210, test error 50.75
# Epoch   300, train loss 1.013873, train error 33.72,  test loss 1.501828, test error 52.28
# Epoch   400, train loss 0.975349, train error 32.55,  test loss 1.580881, test error 52.35
# Epoch   500, train loss 0.959662, train error 32.10,  test loss 1.660799, test error 52.40
# Epoch   600, train loss 0.915121, train error 30.45,  test loss 1.705342, test error 53.60
# Epoch   700, train loss 0.903479, train error 30.03,  test loss 1.793546, test error 53.67
# Epoch   800, train loss 0.896801, train error 29.80,  test loss 1.853520, test error 53.97
# Epoch   900, train loss 0.875699, train error 30.03,  test loss 1.895244, test error 53.72
# Training model with  30 hidden variables
# Epoch     0, train loss 2.141672, train error 78.43,  test loss 2.110712, test error 79.25
# Epoch   100, train loss 1.116378, train error 36.75,  test loss 1.362046, test error 49.33
# Epoch   200, train loss 0.926063, train error 30.75,  test loss 1.563798, test error 50.47
# Epoch   300, train loss 0.856223, train error 28.12,  test loss 1.722880, test error 50.97
# Epoch   400, train loss 0.785137, train error 26.53,  test loss 1.890192, test error 51.80
# Epoch   500, train loss 0.762314, train error 24.97,  test loss 2.024618, test error 53.05
# Epoch   600, train loss 0.726353, train error 24.45,  test loss 2.125130, test error 52.90
# Epoch   700, train loss 0.718597, train error 24.50,  test loss 2.278332, test error 54.42
# Epoch   800, train loss 0.693838, train error 23.97,  test loss 2.376744, test error 55.60
# Epoch   900, train loss 0.675554, train error 22.85,  test loss 2.491036, test error 54.75
# Training model with  35 hidden variables
# Epoch     0, train loss 2.097255, train error 79.03,  test loss 2.047557, test error 77.00
# Epoch   100, train loss 1.013737, train error 33.90,  test loss 1.431432, test error 50.20
# Epoch   200, train loss 0.791913, train error 25.80,  test loss 1.720971, test error 52.35
# Epoch   300, train loss 0.659608, train error 22.28,  test loss 2.067233, test error 53.67
# Epoch   400, train loss 0.593744, train error 19.12,  test loss 2.453904, test error 55.00
# Epoch   500, train loss 0.554733, train error 18.70,  test loss 2.728866, test error 54.58
# Epoch   600, train loss 0.515530, train error 17.97,  test loss 2.986633, test error 55.58
# Epoch   700, train loss 0.480710, train error 16.95,  test loss 3.170080, test error 55.85
# Epoch   800, train loss 0.454899, train error 15.30,  test loss 3.353077, test error 56.17
# Epoch   900, train loss 0.458345, train error 16.28,  test loss 3.538185, test error 55.70
# Training model with  40 hidden variables
# Epoch     0, train loss 2.157675, train error 78.85,  test loss 2.133933, test error 78.97
# Epoch   100, train loss 0.946243, train error 30.35,  test loss 1.428652, test error 50.12
# Epoch   200, train loss 0.673561, train error 22.40,  test loss 1.890509, test error 52.53
# Epoch   300, train loss 0.507247, train error 16.05,  test loss 2.460017, test error 54.12
# Epoch   400, train loss 0.425025, train error 13.47,  test loss 3.152967, test error 55.50
# Epoch   500, train loss 0.402157, train error 13.95,  test loss 3.824310, test error 55.12
# Epoch   600, train loss 0.324263, train error 10.90,  test loss 4.459042, test error 56.50
# Epoch   700, train loss 0.362284, train error 13.03,  test loss 5.091178, test error 56.80
# Epoch   800, train loss 0.325691, train error 11.40,  test loss 5.736477, test error 56.78
# Epoch   900, train loss 0.259530, train error 8.93,  test loss 6.383264, test error 57.08
# Training model with  45 hidden variables
# Epoch     0, train loss 2.114601, train error 77.65,  test loss 2.090754, test error 77.78
# Epoch   100, train loss 0.774948, train error 23.93,  test loss 1.524158, test error 49.55
# Epoch   200, train loss 0.466524, train error 14.62,  test loss 2.327069, test error 51.15
# Epoch   300, train loss 0.294519, train error 8.90,  test loss 3.315452, test error 52.22
# Epoch   400, train loss 0.260150, train error 8.85,  test loss 4.581394, test error 54.38
# Epoch   500, train loss 0.196644, train error 6.50,  test loss 5.775134, test error 54.20
# Epoch   600, train loss 0.134104, train error 4.25,  test loss 6.903976, test error 54.10
# Epoch   700, train loss 0.013216, train error 0.00,  test loss 7.997872, test error 54.92
# Epoch   800, train loss 0.008281, train error 0.00,  test loss 8.683542, test error 54.75
# Epoch   900, train loss 0.006078, train error 0.00,  test loss 9.187375, test error 54.97
# Training model with  50 hidden variables
# Epoch     0, train loss 2.124247, train error 78.47,  test loss 2.097423, test error 77.75
# Epoch   100, train loss 0.692259, train error 20.70,  test loss 1.571435, test error 49.42
# Epoch   200, train loss 0.314288, train error 8.38,  test loss 2.574759, test error 51.47
# Epoch   300, train loss 0.130779, train error 2.78,  test loss 4.079853, test error 53.25
# Epoch   400, train loss 0.027630, train error 0.00,  test loss 5.589561, test error 53.65
# Epoch   500, train loss 0.013184, train error 0.00,  test loss 6.492231, test error 53.85
# Epoch   600, train loss 0.008339, train error 0.00,  test loss 7.088607, test error 54.00
# Epoch   700, train loss 0.005993, train error 0.00,  test loss 7.526905, test error 54.17
# Epoch   800, train loss 0.004644, train error 0.00,  test loss 7.889255, test error 54.17
# Epoch   900, train loss 0.003741, train error 0.00,  test loss 8.184291, test error 54.25
# Training model with  55 hidden variables
# Epoch     0, train loss 2.094731, train error 76.60,  test loss 2.070011, test error 77.47
# Epoch   100, train loss 0.638138, train error 19.35,  test loss 1.668035, test error 51.15
# Epoch   200, train loss 0.202922, train error 4.82,  test loss 2.984316, test error 52.47
# Epoch   300, train loss 0.036568, train error 0.03,  test loss 4.671816, test error 54.15
# Epoch   400, train loss 0.013853, train error 0.00,  test loss 5.642382, test error 54.47
# Epoch   500, train loss 0.008089, train error 0.00,  test loss 6.226760, test error 54.47
# Epoch   600, train loss 0.005630, train error 0.00,  test loss 6.652841, test error 54.42
# Epoch   700, train loss 0.004222, train error 0.00,  test loss 6.985923, test error 54.58
# Epoch   800, train loss 0.003346, train error 0.00,  test loss 7.261074, test error 54.65
# Epoch   900, train loss 0.002740, train error 0.00,  test loss 7.485506, test error 54.67
# Training model with  60 hidden variables
# Epoch     0, train loss 2.024437, train error 75.57,  test loss 1.968048, test error 75.50
# Epoch   100, train loss 0.516029, train error 14.95,  test loss 1.848675, test error 52.92
# Epoch   200, train loss 0.112975, train error 1.38,  test loss 3.633265, test error 54.70
# Epoch   300, train loss 0.019126, train error 0.03,  test loss 4.917434, test error 54.65
# Epoch   400, train loss 0.009390, train error 0.00,  test loss 5.624521, test error 55.00
# Epoch   500, train loss 0.005930, train error 0.00,  test loss 6.079246, test error 55.22
# Epoch   600, train loss 0.004246, train error 0.00,  test loss 6.423117, test error 55.28
# Epoch   700, train loss 0.003236, train error 0.00,  test loss 6.686762, test error 55.12
# Epoch   800, train loss 0.002610, train error 0.00,  test loss 6.911591, test error 55.20
# Epoch   900, train loss 0.002171, train error 0.00,  test loss 7.100425, test error 55.17
# Training model with  70 hidden variables
# Epoch     0, train loss 2.012487, train error 74.00,  test loss 1.974105, test error 74.25
# Epoch   100, train loss 0.365970, train error 9.30,  test loss 2.051741, test error 54.00
# Epoch   200, train loss 0.035706, train error 0.03,  test loss 3.795851, test error 55.95
# Epoch   300, train loss 0.011194, train error 0.00,  test loss 4.624269, test error 55.95
# Epoch   400, train loss 0.006274, train error 0.00,  test loss 5.092710, test error 56.05
# Epoch   500, train loss 0.004216, train error 0.00,  test loss 5.422068, test error 56.08
# Epoch   600, train loss 0.003112, train error 0.00,  test loss 5.669784, test error 56.15
# Epoch   700, train loss 0.002445, train error 0.00,  test loss 5.872576, test error 56.25
# Epoch   800, train loss 0.001997, train error 0.00,  test loss 6.042782, test error 56.42
# Epoch   900, train loss 0.001677, train error 0.00,  test loss 6.185996, test error 56.20
# Training model with  80 hidden variables
# Epoch     0, train loss 2.019826, train error 74.70,  test loss 1.959548, test error 74.47
# Epoch   100, train loss 0.206449, train error 2.75,  test loss 2.111762, test error 51.03
# Epoch   200, train loss 0.018989, train error 0.00,  test loss 3.439203, test error 52.20
# Epoch   300, train loss 0.007845, train error 0.00,  test loss 3.974967, test error 52.25
# Epoch   400, train loss 0.004671, train error 0.00,  test loss 4.298347, test error 52.28
# Epoch   500, train loss 0.003226, train error 0.00,  test loss 4.525097, test error 52.22
# Epoch   600, train loss 0.002425, train error 0.00,  test loss 4.703630, test error 52.22
# Epoch   700, train loss 0.001927, train error 0.00,  test loss 4.847661, test error 52.10
# Epoch   800, train loss 0.001588, train error 0.00,  test loss 4.970652, test error 52.12
# Epoch   900, train loss 0.001343, train error 0.00,  test loss 5.076133, test error 52.22
# Training model with  90 hidden variables
# Epoch     0, train loss 2.020146, train error 74.32,  test loss 1.980698, test error 75.00
# Epoch   100, train loss 0.127129, train error 0.70,  test loss 2.163845, test error 50.58
# Epoch   200, train loss 0.014456, train error 0.00,  test loss 3.144070, test error 51.80
# Epoch   300, train loss 0.006428, train error 0.00,  test loss 3.555111, test error 51.85
# Epoch   400, train loss 0.003948, train error 0.00,  test loss 3.804349, test error 51.62
# Epoch   500, train loss 0.002773, train error 0.00,  test loss 3.989136, test error 51.85
# Epoch   600, train loss 0.002111, train error 0.00,  test loss 4.130455, test error 51.70
# Epoch   700, train loss 0.001689, train error 0.00,  test loss 4.250381, test error 51.70
# Epoch   800, train loss 0.001398, train error 0.00,  test loss 4.349092, test error 51.60
# Epoch   900, train loss 0.001188, train error 0.00,  test loss 4.436150, test error 51.58
# Training model with 100 hidden variables
# Epoch     0, train loss 1.998876, train error 74.07,  test loss 1.944353, test error 74.12
# Epoch   100, train loss 0.096688, train error 0.18,  test loss 2.292287, test error 52.35
# Epoch   200, train loss 0.012091, train error 0.00,  test loss 3.184166, test error 52.47
# Epoch   300, train loss 0.005614, train error 0.00,  test loss 3.556038, test error 52.65
# Epoch   400, train loss 0.003496, train error 0.00,  test loss 3.787014, test error 52.62
# Epoch   500, train loss 0.002489, train error 0.00,  test loss 3.955755, test error 52.65
# Epoch   600, train loss 0.001905, train error 0.00,  test loss 4.087387, test error 52.47
# Epoch   700, train loss 0.001532, train error 0.00,  test loss 4.194980, test error 52.50
# Epoch   800, train loss 0.001273, train error 0.00,  test loss 4.285520, test error 52.40
# Epoch   900, train loss 0.001084, train error 0.00,  test loss 4.365815, test error 52.47
# Training model with 120 hidden variables
# Epoch     0, train loss 1.985308, train error 75.10,  test loss 1.901940, test error 73.88
# Epoch   100, train loss 0.051307, train error 0.00,  test loss 2.227247, test error 50.75
# Epoch   200, train loss 0.009761, train error 0.00,  test loss 2.840503, test error 50.78
# Epoch   300, train loss 0.004843, train error 0.00,  test loss 3.115180, test error 50.62
# Epoch   400, train loss 0.003088, train error 0.00,  test loss 3.301392, test error 50.90
# Epoch   500, train loss 0.002228, train error 0.00,  test loss 3.436535, test error 50.95
# Epoch   600, train loss 0.001720, train error 0.00,  test loss 3.543652, test error 51.05
# Epoch   700, train loss 0.001390, train error 0.00,  test loss 3.631687, test error 51.08
# Epoch   800, train loss 0.001160, train error 0.00,  test loss 3.707301, test error 51.00
# Epoch   900, train loss 0.000992, train error 0.00,  test loss 3.772788, test error 51.00
# Training model with 140 hidden variables
# Epoch     0, train loss 1.955815, train error 71.57,  test loss 1.880358, test error 72.53
# Epoch   100, train loss 0.035795, train error 0.00,  test loss 2.162136, test error 49.33
# Epoch   200, train loss 0.008014, train error 0.00,  test loss 2.658781, test error 49.58
# Epoch   300, train loss 0.004115, train error 0.00,  test loss 2.891990, test error 49.47
# Epoch   400, train loss 0.002675, train error 0.00,  test loss 3.045499, test error 49.53
# Epoch   500, train loss 0.001945, train error 0.00,  test loss 3.160809, test error 49.72
# Epoch   600, train loss 0.001514, train error 0.00,  test loss 3.252974, test error 49.65
# Epoch   700, train loss 0.001229, train error 0.00,  test loss 3.328090, test error 49.53
# Epoch   800, train loss 0.001029, train error 0.00,  test loss 3.393771, test error 49.45
# Epoch   900, train loss 0.000882, train error 0.00,  test loss 3.450199, test error 49.53
# Training model with 160 hidden variables
# Epoch     0, train loss 1.939796, train error 72.30,  test loss 1.857287, test error 73.35
# Epoch   100, train loss 0.028566, train error 0.00,  test loss 2.077019, test error 48.45
# Epoch   200, train loss 0.007157, train error 0.00,  test loss 2.462805, test error 48.47
# Epoch   300, train loss 0.003780, train error 0.00,  test loss 2.655370, test error 48.67
# Epoch   400, train loss 0.002491, train error 0.00,  test loss 2.782903, test error 48.83
# Epoch   500, train loss 0.001826, train error 0.00,  test loss 2.878511, test error 48.83
# Epoch   600, train loss 0.001426, train error 0.00,  test loss 2.954697, test error 48.95
# Epoch   700, train loss 0.001162, train error 0.00,  test loss 3.017576, test error 49.05
# Epoch   800, train loss 0.000976, train error 0.00,  test loss 3.072635, test error 48.95
# Epoch   900, train loss 0.000838, train error 0.00,  test loss 3.120013, test error 49.00
# Training model with 180 hidden variables
# Epoch     0, train loss 1.936038, train error 70.97,  test loss 1.852510, test error 72.43
# Epoch   100, train loss 0.024769, train error 0.00,  test loss 2.052067, test error 48.95
# Epoch   200, train loss 0.006705, train error 0.00,  test loss 2.401241, test error 48.60
# Epoch   300, train loss 0.003582, train error 0.00,  test loss 2.579752, test error 48.45
# Epoch   400, train loss 0.002373, train error 0.00,  test loss 2.697635, test error 48.45
# Epoch   500, train loss 0.001745, train error 0.00,  test loss 2.789069, test error 48.53
# Epoch   600, train loss 0.001367, train error 0.00,  test loss 2.861093, test error 48.53
# Epoch   700, train loss 0.001116, train error 0.00,  test loss 2.921445, test error 48.53
# Epoch   800, train loss 0.000938, train error 0.00,  test loss 2.973158, test error 48.58
# Epoch   900, train loss 0.000806, train error 0.00,  test loss 3.018251, test error 48.60
# Training model with 200 hidden variables
# Epoch     0, train loss 1.931377, train error 70.62,  test loss 1.857812, test error 72.53
# Epoch   100, train loss 0.021832, train error 0.00,  test loss 1.982200, test error 47.38
# Epoch   200, train loss 0.006204, train error 0.00,  test loss 2.288504, test error 47.70
# Epoch   300, train loss 0.003362, train error 0.00,  test loss 2.444733, test error 47.67
# Epoch   400, train loss 0.002242, train error 0.00,  test loss 2.549840, test error 47.75
# Epoch   500, train loss 0.001655, train error 0.00,  test loss 2.627904, test error 47.75
# Epoch   600, train loss 0.001299, train error 0.00,  test loss 2.692079, test error 47.70
# Epoch   700, train loss 0.001062, train error 0.00,  test loss 2.745214, test error 47.65
# Epoch   800, train loss 0.000894, train error 0.00,  test loss 2.790493, test error 47.70
# Epoch   900, train loss 0.000769, train error 0.00,  test loss 2.830444, test error 47.67
# Training model with 250 hidden variables
# Epoch     0, train loss 1.939070, train error 70.70,  test loss 1.881963, test error 73.22
# Epoch   100, train loss 0.016507, train error 0.00,  test loss 1.913269, test error 47.17
# Epoch   200, train loss 0.005249, train error 0.00,  test loss 2.162016, test error 46.95
# Epoch   300, train loss 0.002933, train error 0.00,  test loss 2.297493, test error 47.03
# Epoch   400, train loss 0.001983, train error 0.00,  test loss 2.388099, test error 46.83
# Epoch   500, train loss 0.001477, train error 0.00,  test loss 2.458488, test error 46.85
# Epoch   600, train loss 0.001166, train error 0.00,  test loss 2.515590, test error 46.85
# Epoch   700, train loss 0.000958, train error 0.00,  test loss 2.563207, test error 46.85
# Epoch   800, train loss 0.000809, train error 0.00,  test loss 2.604612, test error 46.88
# Epoch   900, train loss 0.000698, train error 0.00,  test loss 2.640287, test error 46.85
# Training model with 300 hidden variables
# Epoch     0, train loss 1.878862, train error 67.85,  test loss 1.778334, test error 69.90
# Epoch   100, train loss 0.014375, train error 0.00,  test loss 1.850420, test error 46.78
# Epoch   200, train loss 0.004792, train error 0.00,  test loss 2.067367, test error 46.50
# Epoch   300, train loss 0.002713, train error 0.00,  test loss 2.186354, test error 46.45
# Epoch   400, train loss 0.001848, train error 0.00,  test loss 2.268572, test error 46.47
# Epoch   500, train loss 0.001383, train error 0.00,  test loss 2.331685, test error 46.50
# Epoch   600, train loss 0.001096, train error 0.00,  test loss 2.382537, test error 46.45
# Epoch   700, train loss 0.000902, train error 0.00,  test loss 2.425058, test error 46.42
# Epoch   800, train loss 0.000763, train error 0.00,  test loss 2.461747, test error 46.42
# Epoch   900, train loss 0.000660, train error 0.00,  test loss 2.493754, test error 46.45
# Training model with 400 hidden variables
# Epoch     0, train loss 1.837623, train error 64.72,  test loss 1.767015, test error 68.18
# Epoch   100, train loss 0.011713, train error 0.00,  test loss 1.753953, test error 45.75
# Epoch   200, train loss 0.004172, train error 0.00,  test loss 1.926703, test error 45.47
# Epoch   300, train loss 0.002417, train error 0.00,  test loss 2.024741, test error 45.65
# Epoch   400, train loss 0.001665, train error 0.00,  test loss 2.092857, test error 45.80
# Epoch   500, train loss 0.001255, train error 0.00,  test loss 2.145211, test error 45.88
# Epoch   600, train loss 0.001000, train error 0.00,  test loss 2.187454, test error 45.88
# Epoch   700, train loss 0.000826, train error 0.00,  test loss 2.223316, test error 45.95
# Epoch   800, train loss 0.000701, train error 0.00,  test loss 2.254022, test error 45.90
# Epoch   900, train loss 0.000608, train error 0.00,  test loss 2.281341, test error 45.88

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
